# %%
import torch 
from torch.nn import functional
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
#datset
data=pd.read_csv("dataset/Iris.csv")
data = data[data["Species"].isin(['Iris-setosa', 'Iris-versicolor'])]
data['Species'] = data['Species'].map({'Iris-setosa': 0, 'Iris-versicolor': 1})
X = data[['SepalLengthCm', 'SepalWidthCm']].values.tolist()
y = list(data['Species'])
print("len of X: ",len(X))
print("len of y: ",len(y))
print(X[:5])
print(y[:5])
X=torch.tensor(X,dtype=torch.float32)
y=torch.tensor(y,dtype=torch.float32)
torch.manual_seed(42)
shuffle_indices= torch.randperm(len(y),dtype=torch.long)
X=X[shuffle_indices]
y=y[shuffle_indices]
x_train,x_test=X[:70],X[70:]
y_train,y_test=y[:70],y[70:]
# Standarization
mu = x_train.mean(dim=0)
sigma = x_train.std(dim=0)
X_train = (x_train - mu) / sigma
X_test = (x_test - mu) / sigma
# Out:
# len of X:  100
# len of y:  100
# [[5.1, 3.5], [4.9, 3.0], [4.7, 3.2], [4.6, 3.1], [5.0, 3.6]]
# [0, 0, 0, 0, 0]

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
# manual implementation of logistic regression
class logistic_regression_manual(): 
    def __init__(self, num_features=2):
        self.num_features = num_features
        self.weights = torch.zeros(num_features,1 ,dtype=torch.float32, device=device)
        self.bias = torch.zeros(1, dtype=torch.float32, device=device)
    def activation(self,x):
        
        # sigmoid=torch.tensor([1/(1+math.exp(-i)) for i in x])   # here is sigmoid function manually calculate. 
        sigmoid= 1/(1+torch.exp(-x))
        return sigmoid
    def forward(self, x):
        x_w = torch.add(torch.matmul(x,self.weights), self.bias).view(-1)
        probs=self.activation(x_w)
        return probs
        
    def backward(self, x, y, probs):  
        grad_loss_y = probs.view(-1)-y
        grad_loss_weights =  torch.matmul(x.t(),grad_loss_y.view(-1)).t() # torch.matmul is used instaed of torch.mm
        grad_loss_bias = torch.sum(grad_loss_y)
        return grad_loss_weights, grad_loss_bias
    
    def perdicted_labels(self, x):
        probs=self.forward(x)
        labels=torch.where(probs>=0.5, 1, 0)
        return labels

    def evaluation(self, x,y):
        y_pred=self.perdicted_labels(x).float()
        acc=sum(p == t for p, t in zip(y_pred, y))/len(y)
        return acc


    def logits(self,probs,y): 
        y_1=torch.matmul(-y.view(-1), torch.log(probs.view(-1)))
        y_0=torch.matmul((1-y).view(-1), torch.log((1-probs).view(-1)))
        return y_1-y_0
    
    def train(self,X,y, epochs=10, lr=0.01):
        error_per_epoch=[]
        for e in range(epochs):
            y_pred=self.forward(X)
            w_grad, b_grad=self.backward(X,y,y_pred)
            self.weights-=w_grad.unsqueeze(1)*lr
            self.bias-=b_grad*lr
            
            loss=(self.logits(self.forward(X),y) / X.size(0)).tolist()
            error_per_epoch.append(loss)
            acc=self.evaluation(X,y)
            print(f"Epoch : {e}  ; Current loss: {loss}; Accuracy: {acc}")
        return error_per_epoch

# %%
x_train=torch.tensor(x_train,device=device, dtype=torch.float32)
y_train=torch.tensor(y_train,device=device, dtype=torch.float32)
model1=logistic_regression_manual()
loss=model1.train(x_train,y_train, epochs=100)
print("weights: ",model1.weights.tolist())
print("bias: ",model1.bias.tolist())
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14252\2983073880.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x_train=torch.tensor(x_train,device=device, dtype=torch.float32)
# C:\Users\HP\AppData\Local\Temp\ipykernel_14252\2983073880.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train=torch.tensor(y_train,device=device, dtype=torch.float32)
# Epoch : 0  ; Current loss: 0.7921351790428162; Accuracy: 0.5285714268684387
# Epoch : 1  ; Current loss: 3.059091329574585; Accuracy: 0.4714285731315613
# Epoch : 2  ; Current loss: 4.343508720397949; Accuracy: 0.5285714268684387
# Epoch : 3  ; Current loss: 1.5869539976119995; Accuracy: 0.4714285731315613
# Epoch : 4  ; Current loss: 4.9040422439575195; Accuracy: 0.5285714268684387
# Epoch : 5  ; Current loss: 0.8354772925376892; Accuracy: 0.4714285731315613
# Epoch : 6  ; Current loss: 3.8345580101013184; Accuracy: 0.5285714268684387
# Epoch : 7  ; Current loss: 1.7572965621948242; Accuracy: 0.4714285731315613
# Epoch : 8  ; Current loss: 4.602991104125977; Accuracy: 0.5285714268684387
# Epoch : 9  ; Current loss: 0.7759355306625366; Accuracy: 0.48571428656578064
# Epoch : 10  ; Current loss: 3.5819926261901855; Accuracy: 0.5285714268684387
# Epoch : 11  ; Current loss: 1.650860071182251; Accuracy: 0.4714285731315613
# Epoch : 12  ; Current loss: 4.289453506469727; Accuracy: 0.5285714268684387
# Epoch : 13  ; Current loss: 0.7488237619400024; Accuracy: 0.5142857432365417
# Epoch : 14  ; Current loss: 3.2775280475616455; Accuracy: 0.5285714268684387
# Epoch : 15  ; Current loss: 1.613252878189087; Accuracy: 0.4714285731315613
# Epoch : 16  ; Current loss: 3.9398245811462402; Accuracy: 0.5285714268684387
# Epoch : 17  ; Current loss: 0.7668458223342896; Accuracy: 0.5285714268684387
# Epoch : 18  ; Current loss: 3.00849986076355; Accuracy: 0.5285714268684387
# Epoch : 19  ; Current loss: 1.541570782661438; Accuracy: 0.4714285731315613
# Epoch : 20  ; Current loss: 3.5692079067230225; Accuracy: 0.5285714268684387
# Epoch : 21  ; Current loss: 0.8121070265769958; Accuracy: 0.5285714268684387
# Epoch : 22  ; Current loss: 2.747598886489868; Accuracy: 0.5285714268684387
# Epoch : 23  ; Current loss: 1.464436411857605; Accuracy: 0.48571428656578064
# Epoch : 24  ; Current loss: 3.175130844116211; Accuracy: 0.5285714268684387
# Epoch : 25  ; Current loss: 0.883262038230896; Accuracy: 0.5285714268684387
# Epoch : 26  ; Current loss: 2.4992640018463135; Accuracy: 0.5285714268684387
# Epoch : 27  ; Current loss: 1.3741323947906494; Accuracy: 0.5142857432365417
# Epoch : 28  ; Current loss: 2.7607688903808594; Accuracy: 0.5285714268684387
# Epoch : 29  ; Current loss: 0.9716243147850037; Accuracy: 0.5285714268684387
# Epoch : 30  ; Current loss: 2.2485687732696533; Accuracy: 0.5285714268684387
# Epoch : 31  ; Current loss: 1.2796481847763062; Accuracy: 0.5142857432365417
# Epoch : 32  ; Current loss: 2.335573434829712; Accuracy: 0.5285714268684387
# Epoch : 33  ; Current loss: 1.0528157949447632; Accuracy: 0.5285714268684387
# Epoch : 34  ; Current loss: 1.9713718891143799; Accuracy: 0.5285714268684387
# Epoch : 35  ; Current loss: 1.1854795217514038; Accuracy: 0.5285714268684387
# Epoch : 36  ; Current loss: 1.909487009048462; Accuracy: 0.5285714268684387
# Epoch : 37  ; Current loss: 1.0769364833831787; Accuracy: 0.5285714268684387
# Epoch : 38  ; Current loss: 1.6430193185806274; Accuracy: 0.5285714268684387
# Epoch : 39  ; Current loss: 1.0627580881118774; Accuracy: 0.5285714268684387
# Epoch : 40  ; Current loss: 1.4667049646377563; Accuracy: 0.5285714268684387
# Epoch : 41  ; Current loss: 0.9627161622047424; Accuracy: 0.5285714268684387
# Epoch : 42  ; Current loss: 1.2074248790740967; Accuracy: 0.5571428537368774
# Epoch : 43  ; Current loss: 0.8086352944374084; Accuracy: 0.5571428537368774
# Epoch : 44  ; Current loss: 0.876350462436676; Accuracy: 0.5857142806053162
# Epoch : 45  ; Current loss: 0.5365513563156128; Accuracy: 0.7857142686843872
# Epoch : 46  ; Current loss: 0.3982323408126831; Accuracy: 0.800000011920929
# Epoch : 47  ; Current loss: 0.15487103164196014; Accuracy: 0.9285714626312256
# Epoch : 48  ; Current loss: 0.06636699289083481; Accuracy: 1.0
# Epoch : 49  ; Current loss: 0.0519343800842762; Accuracy: 1.0
# Epoch : 50  ; Current loss: 0.051519691944122314; Accuracy: 1.0
# Epoch : 51  ; Current loss: 0.05140224099159241; Accuracy: 1.0
# Epoch : 52  ; Current loss: 0.05128970742225647; Accuracy: 1.0
# Epoch : 53  ; Current loss: 0.051177844405174255; Accuracy: 1.0
# Epoch : 54  ; Current loss: 0.05106662958860397; Accuracy: 1.0
# Epoch : 55  ; Current loss: 0.05095605552196503; Accuracy: 1.0
# Epoch : 56  ; Current loss: 0.05084605515003204; Accuracy: 1.0
# Epoch : 57  ; Current loss: 0.050736673176288605; Accuracy: 1.0
# Epoch : 58  ; Current loss: 0.05062789097428322; Accuracy: 1.0
# Epoch : 59  ; Current loss: 0.05051971599459648; Accuracy: 1.0
# Epoch : 60  ; Current loss: 0.0504121296107769; Accuracy: 1.0
# Epoch : 61  ; Current loss: 0.050305139273405075; Accuracy: 1.0
# Epoch : 62  ; Current loss: 0.05019871145486832; Accuracy: 1.0
# Epoch : 63  ; Current loss: 0.05009287968277931; Accuracy: 1.0
# Epoch : 64  ; Current loss: 0.04998762533068657; Accuracy: 1.0
# Epoch : 65  ; Current loss: 0.049882929772138596; Accuracy: 1.0
# Epoch : 66  ; Current loss: 0.049778807908296585; Accuracy: 1.0
# Epoch : 67  ; Current loss: 0.049675218760967255; Accuracy: 1.0
# Epoch : 68  ; Current loss: 0.04957219213247299; Accuracy: 1.0
# Epoch : 69  ; Current loss: 0.0494697168469429; Accuracy: 1.0
# Epoch : 70  ; Current loss: 0.049367789179086685; Accuracy: 1.0
# Epoch : 71  ; Current loss: 0.04926636442542076; Accuracy: 1.0
# Epoch : 72  ; Current loss: 0.0491655133664608; Accuracy: 1.0
# Epoch : 73  ; Current loss: 0.04906516522169113; Accuracy: 1.0
# Epoch : 74  ; Current loss: 0.04896535724401474; Accuracy: 1.0
# Epoch : 75  ; Current loss: 0.04886605590581894; Accuracy: 1.0
# Epoch : 76  ; Current loss: 0.04876728728413582; Accuracy: 1.0
# Epoch : 77  ; Current loss: 0.048669010400772095; Accuracy: 1.0
# Epoch : 78  ; Current loss: 0.04857126623392105; Accuracy: 1.0
# Epoch : 79  ; Current loss: 0.04847400635480881; Accuracy: 1.0
# Epoch : 80  ; Current loss: 0.048377227038145065; Accuracy: 1.0
# Epoch : 81  ; Current loss: 0.04828096181154251; Accuracy: 1.0
# Epoch : 82  ; Current loss: 0.04818519204854965; Accuracy: 1.0
# Epoch : 83  ; Current loss: 0.04808991774916649; Accuracy: 1.0
# Epoch : 84  ; Current loss: 0.04799511656165123; Accuracy: 1.0
# Epoch : 85  ; Current loss: 0.047900766134262085; Accuracy: 1.0
# Epoch : 86  ; Current loss: 0.04780692607164383; Accuracy: 1.0
# Epoch : 87  ; Current loss: 0.04771353304386139; Accuracy: 1.0
# Epoch : 88  ; Current loss: 0.047620609402656555; Accuracy: 1.0
# Epoch : 89  ; Current loss: 0.047528158873319626; Accuracy: 1.0
# Epoch : 90  ; Current loss: 0.04743615910410881; Accuracy: 1.0
# Epoch : 91  ; Current loss: 0.047344617545604706; Accuracy: 1.0
# Epoch : 92  ; Current loss: 0.047253526747226715; Accuracy: 1.0
# Epoch : 93  ; Current loss: 0.047162871807813644; Accuracy: 1.0
# Epoch : 94  ; Current loss: 0.04707268998026848; Accuracy: 1.0
# Epoch : 95  ; Current loss: 0.04698289930820465; Accuracy: 1.0
# Epoch : 96  ; Current loss: 0.04689359664916992; Accuracy: 1.0
# Epoch : 97  ; Current loss: 0.04680471494793892; Accuracy: 1.0
# Epoch : 98  ; Current loss: 0.046716246753931046; Accuracy: 1.0
# Epoch : 99  ; Current loss: 0.04662822186946869; Accuracy: 1.0
# weights:  [[4.145534038543701], [-6.945319175720215]]
# bias:  [-0.6250685453414917]

# %%
plt.plot(range(len(loss)), loss)
plt.ylabel('Mean Square Error')
plt.xlabel('Epochs')
plt.show()

# %%
w, b = model1.weights.view(-1), model1.bias

x_min = -2
y_min = ( (-(w[0] * x_min) - b[0]) 
          / w[1] ).item()

x_max = 2
y_max = ( (-(w[0] * x_max) - b[0]) 
          / w[1] ).item()


fig, ax = plt.subplots(1, 2, sharex=True, figsize=(7, 3))
ax[0].plot([x_min, x_max], [y_min, y_max])
ax[1].plot([x_min, x_max], [y_min, y_max])
x_train_plt=X_train.to('cpu')
x_test_plt=X_test.to('cpu')
y_test_plt=y_test.to('cpu')
y_train_plt=y_train.to('cpu')
ax[0].scatter(x_train_plt[y_train_plt==0, 0], x_train_plt[y_train_plt==0, 1], label='class 0', marker='o')
ax[0].scatter(x_train_plt[y_train_plt==1, 0], x_train_plt[y_train_plt==1, 1], label='class 1', marker='s')

ax[1].scatter(x_test_plt[y_test_plt==0, 0], x_test_plt[y_test_plt==0, 1], label='class 0', marker='o')
ax[1].scatter(x_test_plt[y_test_plt==1, 0], x_test_plt[y_test_plt==1, 1], label='class 1', marker='s')

ax[1].legend(loc='upper left')
plt.show()

# %%
X_test= torch.tensor(X_test, dtype=torch.float32, device=device)
y_test = torch.tensor(y_test, dtype=torch.float32, device=device).view(-1, 1)
test_results=model1.forward(X_test)
test_class=[1 if i>=0.5 else 0 for i in test_results]
correct= sum(p == t for p, t in zip(test_class, y_test))
print("Correct : ",correct.tolist())
print("Wrong: ",len(y_test)-correct.item())
print("Accuracy: ", correct.item()/len(y_test) )
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14252\424987519.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_test= torch.tensor(X_test, dtype=torch.float32, device=device)
# Correct :  [29]
# Wrong:  1
# Accuracy:  0.9666666666666667
# C:\Users\HP\AppData\Local\Temp\ipykernel_14252\424987519.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test = torch.tensor(y_test, dtype=torch.float32, device=device).view(-1, 1)

# %%
class Logistic_regression(torch.nn.Module):
    def __init__(self, num_features=2):
        super(Logistic_regression, self).__init__()
        self.layer=torch.nn.Linear(num_features,1)
        self.layer.weight.detach().zero_()
        self.layer.bias.detach().zero_()
    
    def forward(self, x):
        logits=self.layer(x)
        probs=functional.sigmoid(logits)
        return probs

def accuracy(y, pred_prob):
    pred_prob=pred_prob.view(-1).float()
    y_pred=torch.where(pred_prob >= 0.5, 1, 0)
    acc=sum(p == t for p, t in zip(y_pred, y))/len(y)
    return acc

def train(X,y,model, epochs=10, lr=0.01):
    loss_per_epoch=[]
    optimizer = torch.optim.SGD(model.parameters(), lr=lr) 

    for e in range(epochs):
        y_pred=model(X)
        loss=functional.binary_cross_entropy(y_pred, y, reduction='sum')
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        y_pred=model(X)
        acc=accuracy(y,y_pred).item()
        loss=functional.binary_cross_entropy(y_pred, y)
        print(f"Epoch : {e}  ; Current loss: {loss}; Accuracy: {acc}")
        ls=loss.item()
        loss_per_epoch.append(ls)
    return loss_per_epoch

# %%
model2=Logistic_regression().to(device)
X_train = torch.tensor(X_train, dtype=torch.float32, device=device)
y_train = torch.tensor(y_train, dtype=torch.float32, device=device).view(-1, 1)
loss=train(X_train,y_train,model2, epochs=100)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14252\3888722327.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_train = torch.tensor(X_train, dtype=torch.float32, device=device)
# C:\Users\HP\AppData\Local\Temp\ipykernel_14252\3888722327.py:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y_train, dtype=torch.float32, device=device).view(-1, 1)
# Epoch : 0  ; Current loss: 0.5318381786346436; Accuracy: 1.0
# Epoch : 1  ; Current loss: 0.42960721254348755; Accuracy: 1.0
# Epoch : 2  ; Current loss: 0.36141592264175415; Accuracy: 1.0
# Epoch : 3  ; Current loss: 0.3132934868335724; Accuracy: 1.0
# Epoch : 4  ; Current loss: 0.27764955163002014; Accuracy: 1.0
# Epoch : 5  ; Current loss: 0.2501968741416931; Accuracy: 1.0
# Epoch : 6  ; Current loss: 0.22838212549686432; Accuracy: 1.0
# Epoch : 7  ; Current loss: 0.21060523390769958; Accuracy: 1.0
# Epoch : 8  ; Current loss: 0.19581761956214905; Accuracy: 1.0
# Epoch : 9  ; Current loss: 0.18330511450767517; Accuracy: 1.0
# Epoch : 10  ; Current loss: 0.17256514728069305; Accuracy: 1.0
# Epoch : 11  ; Current loss: 0.16323386132717133; Accuracy: 1.0
# Epoch : 12  ; Current loss: 0.15504147112369537; Accuracy: 1.0
# Epoch : 13  ; Current loss: 0.1477835774421692; Accuracy: 1.0
# Epoch : 14  ; Current loss: 0.14130251109600067; Accuracy: 1.0
# Epoch : 15  ; Current loss: 0.13547460734844208; Accuracy: 1.0
# Epoch : 16  ; Current loss: 0.13020150363445282; Accuracy: 1.0
# Epoch : 17  ; Current loss: 0.12540392577648163; Accuracy: 1.0
# Epoch : 18  ; Current loss: 0.12101726233959198; Accuracy: 1.0
# Epoch : 19  ; Current loss: 0.11698831617832184; Accuracy: 1.0
# Epoch : 20  ; Current loss: 0.11327281594276428; Accuracy: 1.0
# Epoch : 21  ; Current loss: 0.10983368009328842; Accuracy: 1.0
# Epoch : 22  ; Current loss: 0.1066395565867424; Accuracy: 1.0
# Epoch : 23  ; Current loss: 0.10366372764110565; Accuracy: 1.0
# Epoch : 24  ; Current loss: 0.100883349776268; Accuracy: 1.0
# Epoch : 25  ; Current loss: 0.09827867150306702; Accuracy: 1.0
# Epoch : 26  ; Current loss: 0.09583263099193573; Accuracy: 1.0
# Epoch : 27  ; Current loss: 0.0935303270816803; Accuracy: 1.0
# Epoch : 28  ; Current loss: 0.09135870635509491; Accuracy: 1.0
# Epoch : 29  ; Current loss: 0.0893062874674797; Accuracy: 1.0
# Epoch : 30  ; Current loss: 0.08736293762922287; Accuracy: 1.0
# Epoch : 31  ; Current loss: 0.08551966398954391; Accuracy: 1.0
# Epoch : 32  ; Current loss: 0.08376846462488174; Accuracy: 1.0
# Epoch : 33  ; Current loss: 0.08210216462612152; Accuracy: 1.0
# Epoch : 34  ; Current loss: 0.08051439374685287; Accuracy: 1.0
# Epoch : 35  ; Current loss: 0.0789993405342102; Accuracy: 1.0
# Epoch : 36  ; Current loss: 0.07755184173583984; Accuracy: 1.0
# Epoch : 37  ; Current loss: 0.07616717368364334; Accuracy: 1.0
# Epoch : 38  ; Current loss: 0.07484106719493866; Accuracy: 1.0
# Epoch : 39  ; Current loss: 0.07356967031955719; Accuracy: 1.0
# Epoch : 40  ; Current loss: 0.0723494291305542; Accuracy: 1.0
# Epoch : 41  ; Current loss: 0.07117711752653122; Accuracy: 1.0
# Epoch : 42  ; Current loss: 0.07004979252815247; Accuracy: 1.0
# Epoch : 43  ; Current loss: 0.06896474212408066; Accuracy: 1.0
# Epoch : 44  ; Current loss: 0.06791947782039642; Accuracy: 1.0
# Epoch : 45  ; Current loss: 0.06691170483827591; Accuracy: 1.0
# Epoch : 46  ; Current loss: 0.06593931466341019; Accuracy: 1.0
# Epoch : 47  ; Current loss: 0.06500035524368286; Accuracy: 1.0
# Epoch : 48  ; Current loss: 0.06409300118684769; Accuracy: 1.0
# Epoch : 49  ; Current loss: 0.06321558356285095; Accuracy: 1.0
# Epoch : 50  ; Current loss: 0.06236656755208969; Accuracy: 1.0
# Epoch : 51  ; Current loss: 0.061544474214315414; Accuracy: 1.0
# Epoch : 52  ; Current loss: 0.06074797734618187; Accuracy: 1.0
# Epoch : 53  ; Current loss: 0.05997580289840698; Accuracy: 1.0
# Epoch : 54  ; Current loss: 0.05922679975628853; Accuracy: 1.0
# Epoch : 55  ; Current loss: 0.05849985405802727; Accuracy: 1.0
# Epoch : 56  ; Current loss: 0.057793959975242615; Accuracy: 1.0
# Epoch : 57  ; Current loss: 0.057108137756586075; Accuracy: 1.0
# Epoch : 58  ; Current loss: 0.05644148960709572; Accuracy: 1.0
# Epoch : 59  ; Current loss: 0.055793166160583496; Accuracy: 1.0
# Epoch : 60  ; Current loss: 0.05516238138079643; Accuracy: 1.0
# Epoch : 61  ; Current loss: 0.05454837158322334; Accuracy: 1.0
# Epoch : 62  ; Current loss: 0.05395043268799782; Accuracy: 1.0
# Epoch : 63  ; Current loss: 0.053367920219898224; Accuracy: 1.0
# Epoch : 64  ; Current loss: 0.05280018597841263; Accuracy: 1.0
# Epoch : 65  ; Current loss: 0.05224663391709328; Accuracy: 1.0
# Epoch : 66  ; Current loss: 0.051706712692976; Accuracy: 1.0
# Epoch : 67  ; Current loss: 0.05117988586425781; Accuracy: 1.0
# Epoch : 68  ; Current loss: 0.050665657967329025; Accuracy: 1.0
# Epoch : 69  ; Current loss: 0.05016353353857994; Accuracy: 1.0
# Epoch : 70  ; Current loss: 0.04967309534549713; Accuracy: 1.0
# Epoch : 71  ; Current loss: 0.04919387400150299; Accuracy: 1.0
# Epoch : 72  ; Current loss: 0.04872549697756767; Accuracy: 1.0
# Epoch : 73  ; Current loss: 0.04826755449175835; Accuracy: 1.0
# Epoch : 74  ; Current loss: 0.047819677740335464; Accuracy: 1.0
# Epoch : 75  ; Current loss: 0.047381527721881866; Accuracy: 1.0
# Epoch : 76  ; Current loss: 0.046952757984399796; Accuracy: 1.0
# Epoch : 77  ; Current loss: 0.046533070504665375; Accuracy: 1.0
# Epoch : 78  ; Current loss: 0.04612213373184204; Accuracy: 1.0
# Epoch : 79  ; Current loss: 0.045719679445028305; Accuracy: 1.0
# Epoch : 80  ; Current loss: 0.045325420796871185; Accuracy: 1.0
# Epoch : 81  ; Current loss: 0.04493908956646919; Accuracy: 1.0
# Epoch : 82  ; Current loss: 0.044560447335243225; Accuracy: 1.0
# Epoch : 83  ; Current loss: 0.04418923705816269; Accuracy: 1.0
# Epoch : 84  ; Current loss: 0.04382522404193878; Accuracy: 1.0
# Epoch : 85  ; Current loss: 0.04346819967031479; Accuracy: 1.0
# Epoch : 86  ; Current loss: 0.0431179478764534; Accuracy: 1.0
# Epoch : 87  ; Current loss: 0.0427742674946785; Accuracy: 1.0
# Epoch : 88  ; Current loss: 0.042436957359313965; Accuracy: 1.0
# Epoch : 89  ; Current loss: 0.04210583120584488; Accuracy: 1.0
# Epoch : 90  ; Current loss: 0.04178071767091751; Accuracy: 1.0
# Epoch : 91  ; Current loss: 0.04146142676472664; Accuracy: 1.0
# Epoch : 92  ; Current loss: 0.041147809475660324; Accuracy: 1.0
# Epoch : 93  ; Current loss: 0.04083969444036484; Accuracy: 1.0
# Epoch : 94  ; Current loss: 0.04053693637251854; Accuracy: 1.0
# Epoch : 95  ; Current loss: 0.040239397436380386; Accuracy: 1.0
# Epoch : 96  ; Current loss: 0.039946895092725754; Accuracy: 1.0
# Epoch : 97  ; Current loss: 0.03965933620929718; Accuracy: 1.0
# Epoch : 98  ; Current loss: 0.03937657177448273; Accuracy: 1.0
# Epoch : 99  ; Current loss: 0.039098482578992844; Accuracy: 1.0

# %%
print("weight: ",model2.layer.weight)
print("bias: ",model2.layer.bias)
# Out:
# weight:  Parameter containing:
# tensor([[ 3.2207, -3.0045]], device='cuda:0', requires_grad=True)
# bias:  Parameter containing:
# tensor([0.5089], device='cuda:0', requires_grad=True)

# %%
plt.plot(range(len(loss)), loss)
plt.ylabel('Mean Square Error')
plt.xlabel('Epochs')
plt.show()

# %%
w, b = model2.layer.weight.detach().view(-1), model2.layer.bias.detach()

x_min = -2
y_min = ( (-(w[0] * x_min) - b[0]) 
          / w[1] ).item()

x_max = 2
y_max = ( (-(w[0] * x_max) - b[0]) 
          / w[1] ).item()


fig, ax = plt.subplots(1, 2, sharex=True, figsize=(7, 3))
ax[0].plot([x_min, x_max], [y_min, y_max])
ax[1].plot([x_min, x_max], [y_min, y_max])
ax[0].scatter(x_train_plt[y_train_plt==0, 0], x_train_plt[y_train_plt==0, 1], label='class 0', marker='o')
ax[0].scatter(x_train_plt[y_train_plt==1, 0], x_train_plt[y_train_plt==1, 1], label='class 1', marker='s')

ax[1].scatter(x_test_plt[y_test_plt==0, 0], x_test_plt[y_test_plt==0, 1], label='class 0', marker='o')
ax[1].scatter(x_test_plt[y_test_plt==1, 0], x_test_plt[y_test_plt==1, 1], label='class 1', marker='s')

ax[1].legend(loc='upper left')
plt.show()

# %%
test_results=model2(X_test)
test_class=[1 if i>=0.5 else 0 for i in test_results]
correct= sum(p == t for p, t in zip(test_class, y_test))
print("Correct : ",correct.tolist())
print("Wrong: ",len(y_test)-correct.item())
print("Accuracy: ", correct.item()/len(y_test) )
# Out:
# Correct :  [29]
# Wrong:  1
# Accuracy:  0.9666666666666667
